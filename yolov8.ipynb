# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 11.1 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model

# %%
result = model.train(data='/kaggle/input/trytomakeadataset/datasets.yaml', epochs=100)
# Out:
# Ultralytics YOLOv8.0.154 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO('/kaggle/input/yolomodeltrained/last.pt')

# %%
result = model.predict('/kaggle/input/trytomakeadataset/Data/images/train/images/traffic-light-21-_jpg.rf.71ec01eb53994d06fb0996d6d693ce79.jpg', save = True)
# Out:
# image 1/1 /kaggle/input/trytomakeadataset/Data/images/train/images/traffic-light-21-_jpg.rf.71ec01eb53994d06fb0996d6d693ce79.jpg: 640x640 1 red, 11.2ms
# Speed: 2.7ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
img = cv2.imread('/kaggle/input/trytomakeadataset/Data/images/train/images/traffic-light-21-_jpg.rf.71ec01eb53994d06fb0996d6d693ce79.jpg')

# %%
# Convert BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Display image with matplotlib
plt.imshow(img)  
plt.title('Image')
plt.xticks([]) # hide x-axis ticks
plt.yticks([]) # hide y-axis ticks
plt.show()

# %%
img = cv2.imread('/kaggle/working/runs/detect/predict/traffic-light-21-_jpg.rf.71ec01eb53994d06fb0996d6d693ce79.jpg')  
# Convert BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# Display image with matplotlib
plt.imshow(img)  
plt.title('Image')
plt.xticks([]) # hide x-axis ticks
plt.yticks([]) # hide y-axis ticks
plt.show()
